# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#        timestamp     angle  curLapTime  damage  distFromStart  distRaced  \
# 0  821183.127360  0.002403      -0.982     1.0         2922.6        0.0
# 1  821183.159784  0.002403      -0.962     1.0         2922.6        0.0
# 2  821183.172128  0.002403      -0.942     1.0         2922.6        0.0
# 3  821183.185629  0.002403      -0.922     1.0         2922.6        0.0
# 4  821183.203702  0.002403      -0.902     1.0         2922.6        0.0
#
#    fuel  gear  lastLapTime  racePos  ...  relative_opponent_speed  \
# 0  94.0     1          0.0      4.0  ...                      0.0
# 1  94.0     1          0.0      4.0  ...                      0.0
# 2  94.0     1          0.0      4.0  ...                      0.0
# 3  94.0     1          0.0      4.0  ...                      0.0
# 4  94.0     1          0.0      4.0  ...                      0.0
#
#    minimum_track_distance  track_curvature  track_width  num_nearby_opponents  \
# ...
